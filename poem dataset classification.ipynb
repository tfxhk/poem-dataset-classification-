# %% [markdown]
# # Poem
# Dataset is classified in 4 poem genres :Affection,Environment,Music and Death
# Classify the genres based on NLP METHOD.

# %% [markdown]
# # ✅ Dataset Summary
# File Name	Poem_classification - test_data.csv
#
# Dataset Type	Tabular
#
# Task Type	Likely Text Classification (based on Genre)
#
# Number of Rows	841
#
# Number of Columns	2
#
# Columns	Genre, Poem
#
# Target Column	Genre
#
# Input Features	Poem (free-form text)
#
# Missing Values	Poem has 4 missing entries (837/841)
#
# Data Types	Both columns are of type object (string)
#
# Unique Genres	Depends on the dataset — likely multiple poetry types (e.g., Romantic, Epic, etc.)
#
# Data Size	~13.3 KB (lightweight dataset)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Reading data

# %%
data = pd.read_csv('Poem_classification - train_data.csv')
data.head()
# Out:
#    Genre                                               Poem
# 0  Music                                                NaN
# 1  Music                In the thick brushthey spend the...
# 2  Music     Storms are generous.                       ...
# 3  Music   —After Ana Mendieta Did you carry around the ...
# 4  Music   for Aja Sherrard at 20The portent may itself ...

# %%
data = pd.read_csv('Poem_classification - test_data.csv')
data.head()
# Out:
#    Genre                                               Poem
# 0  Music  A woman walks by the bench I’m sitting onwith ...
# 1  Music  Because I am a boy, the untouchability of beau...
# 2  Music  Because today we did not leave this world,We n...
# 3  Music  Big Bend has been here, been here. Shouldn’t i...
# 4  Music  I put shells there, along the lip of the road....

# %%
data.head(2)
# Out:
#    Genre                                               Poem
# 0  Music  A woman walks by the bench I’m sitting onwith ...
# 1  Music  Because I am a boy, the untouchability of beau...

# %%
data.shape
# Out:
# (150, 2)

# %%
data.sample()
# Out:
#     Genre                                               Poem
# 17  Death  If only each line of a poem could be its true ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Genre   150 non-null    object
#  1   Poem    150 non-null    object
# dtypes: object(2)
# memory usage: 2.5+ KB

# %%
data.describe()
# Out:
#             Genre                                               Poem
# count         150                                                150
# unique          4                                                150
# top     Affection  A woman walks by the bench I’m sitting onwith ...
# freq          100                                                  1

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
data.isnull().sum()
# Out:
# Genre    0
# Poem     0
# dtype: int64

# %%
data.shape
# Out:
# (150, 2)

# %% [markdown]
# # Drop Genre

# %%
df = pd.DataFrame(data)
df = df.drop('Genre', axis=1)

# %% [markdown]
# # Separate target & features

# %%
df['poem_length'] = df['Poem'].apply(lambda x: len(x.split()))

# %%
X = df['Poem']
y = df['poem_length']

# %% [markdown]
# # Convert text to TF-IDF vectors

# %%
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(X)

# %% [markdown]
# # Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Train Linear Regression model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Features and target

# %%
X = df['Poem']
y = df['poem_length']

# %% [markdown]
# # Convert text to TF-IDF vectors

# %%
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(X)

# %% [markdown]
# # Train-test split

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predict

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Evaluate

# %%
print("✅ Model Evaluation")
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# ✅ Model Evaluation
# Mean Squared Error: 210.62356042309167
# R² Score: 0.07312286383078825

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 1. Handle missing values

# %%
df.dropna(inplace=True)

# %% [markdown]
# # 2. Create numeric target: Poem length (word count)

# %%
df['poem_length'] = df['Poem'].apply(lambda x: len(x.split()))

# %% [markdown]
# # 3. Detect & remove outliers using IQR method

# %%
Q1 = df['poem_length'].quantile(0.25)
Q3 = df['poem_length'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['poem_length'] >= lower_bound) & (df['poem_length'] <= upper_bound)]

# %% [markdown]
# # 4. Feature extraction using TF-IDF

# %%
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(df['Poem'])

# %% [markdown]
# # 5. Scale the TF-IDF features

# %%
scaler = StandardScaler(with_mean=False)
X_scaled = scaler.fit_transform(X_tfidf)

# %% [markdown]
# # 6. Define target

# %%
y = df['poem_length']

# %% [markdown]
# # 7. Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # 8. Train Linear Regression model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 9. Predict and evaluate

# %%
y_pred = model.predict(X_test)

# %%
print("✅ Model Evaluation")
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# ✅ Model Evaluation
# Mean Squared Error: 40.527611334639474
# R² Score: -0.020469351442117478
